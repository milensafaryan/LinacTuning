# %%
import analyze_scan_data as ana

# %%
path = r'/Users/rshara01-local/Desktop/LINAC_STUDY/'

# %%
files = ana.get_files(path)
labels = ana.get_labels(files)
print(labels)
# Out:
# ['07MAR2022_03', '07MAR2022_03_1000', '08MAR2022', '08MAR2022_6008', '09MAR2022_1000', '09MAR2022_1049', '10MAR2022', '11MAR2022_1000', '12MAR2022_1000', '12MAR2022_1000_withchange', '12MAR2022_1000_wochange', '14MAR2022', '14MAR2022_aftertuning']

# %%
#ana.check_col_order(files,'all')

# %%
# define reference date
ref = '07MAR2022'

# define threshold for noisy channel removal
variance = 1

# define threshold in number of sigma for outlier removal
n_sigma = 2.5

# %%
ana.filter_and_plot_multiFile(files,variance,n_sigma,'phase','%s'%ref)

# %%
ana.filter_and_plot_multiFile(files,variance,n_sigma,'bpv','%s'%ref)

# %%
ana.filter_and_plot_multiFile(files,variance,n_sigma,'bph','%s'%ref)

# %%
ana.filter_and_plot_multiFile(files,variance,n_sigma,'blm','%s'%ref)
